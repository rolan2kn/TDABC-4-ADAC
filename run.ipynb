# %%
import sys

proj_path = 'TDABC-4-ADAC'
sys.path.append(proj_path)

# %%
from testing_tools.test_krnn_rocauc import TestKRNN_ROCAUC
from dataset_tools.dataset_types import DatasetTypeHandler
import random

# %%
kwargs = {"option": 3,  # this option is for execute the classification of the 8 datasets
                  "dtype": DatasetTypeHandler.KRNN,
                  "folder": "./docs/ADAC_TDABC_RESULTS",
                  "iterations": 0,
                  "number_of_datasets": 16,
                  "csv_output": True, "can_i_show":True,
                  "metric": "euclidean"}

TestKRNN_ROCAUC().execute(**kwargs)
# Out:
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=0
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=0
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=0
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=1
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=1
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=1
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8777777777777778
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.9023569023569024
# FB-MEASURE:{0.5: 0.9253294598122185, 2: 0.8856469201296787, 3: 0.8813921048645447}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8616178909971062
# GEOMETRIC_MEAN:0.9186604727419022
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=2
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8777777777777778
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.9023569023569024
# FB-MEASURE:{0.5: 0.9253294598122185, 2: 0.8856469201296787, 3: 0.8813921048645447}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8616178909971062
# GEOMETRIC_MEAN:0.9186604727419022
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=2
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8777777777777779
# RECALL:0.7666666666666666
# TRUE_NEGATIVE_RATE:0.9296296296296296
# FALSE_POSITIVE_RATE:0.07037037037037037
# FALSE_POSITIVE_DISCOVERY_RATE:0.12222222222222223
# F1-MEASURE:0.8111111111111112
# FB-MEASURE:{0.5: 0.8474747474747475, 2: 0.7825396825396825, 3: 0.7743295019157088}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7202570560327395
# GEOMETRIC_MEAN:0.8418958947251513
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=2
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8777777777777779
# RECALL:0.7666666666666666
# TRUE_NEGATIVE_RATE:0.9296296296296296
# FALSE_POSITIVE_RATE:0.07037037037037037
# FALSE_POSITIVE_DISCOVERY_RATE:0.12222222222222223
# F1-MEASURE:0.8111111111111112
# FB-MEASURE:{0.5: 0.8474747474747475, 2: 0.7825396825396825, 3: 0.7743295019157088}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7202570560327395
# GEOMETRIC_MEAN:0.8418958947251513
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=3
# METRIC:  euclidean
#
#  INIT propagation
# iteration: tau=[147], p(tau) = 0.1999999999999801
#
#  END propagation in 0.00017786026000976562 seconds with result=[14.12582234  0.          0.        ]
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9523809523809524
# RECALL:0.8666666666666667
# TRUE_NEGATIVE_RATE:0.9629629629629629
# FALSE_POSITIVE_RATE:0.037037037037037035
# FALSE_POSITIVE_DISCOVERY_RATE:0.047619047619047616
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9290382819794584, 2: 0.878136200716846, 3: 0.8720865395338464}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9105544745272983
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=3
# METRIC:  euclidean
#
#  INIT propagation
# iteration: tau=[147], p(tau) = 0.1999999999999801
#
#  END propagation in 0.00017404556274414062 seconds with result=[14.12582234  0.          0.        ]
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9523809523809524
# RECALL:0.8666666666666667
# TRUE_NEGATIVE_RATE:0.9629629629629629
# FALSE_POSITIVE_RATE:0.037037037037037035
# FALSE_POSITIVE_DISCOVERY_RATE:0.047619047619047616
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9290382819794584, 2: 0.878136200716846, 3: 0.8720865395338464}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9105544745272983
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=3
# METRIC:  euclidean
#
#  INIT propagation
# iteration: tau=[147], p(tau) = 0.1999999999999801
#
#  END propagation in 0.0005040168762207031 seconds with result=[4.72135955 0.         0.        ]
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9523809523809524
# RECALL:0.8666666666666667
# TRUE_NEGATIVE_RATE:0.9629629629629629
# FALSE_POSITIVE_RATE:0.037037037037037035
# FALSE_POSITIVE_DISCOVERY_RATE:0.047619047619047616
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9290382819794584, 2: 0.878136200716846, 3: 0.8720865395338464}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9105544745272983
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9523809523809524
# RECALL:0.8666666666666667
# TRUE_NEGATIVE_RATE:0.9629629629629629
# FALSE_POSITIVE_RATE:0.037037037037037035
# FALSE_POSITIVE_DISCOVERY_RATE:0.047619047619047616
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9290382819794584, 2: 0.878136200716846, 3: 0.8720865395338464}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9105544745272983
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9523809523809524
# RECALL:0.8666666666666667
# TRUE_NEGATIVE_RATE:0.9629629629629629
# FALSE_POSITIVE_RATE:0.037037037037037035
# FALSE_POSITIVE_DISCOVERY_RATE:0.047619047619047616
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9290382819794584, 2: 0.878136200716846, 3: 0.8720865395338464}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9105544745272983
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9523809523809524
# RECALL:0.8666666666666667
# TRUE_NEGATIVE_RATE:0.9629629629629629
# FALSE_POSITIVE_RATE:0.037037037037037035
# FALSE_POSITIVE_DISCOVERY_RATE:0.047619047619047616
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9290382819794584, 2: 0.878136200716846, 3: 0.8720865395338464}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9105544745272983
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9523809523809524
# RECALL:0.8666666666666667
# TRUE_NEGATIVE_RATE:0.9629629629629629
# FALSE_POSITIVE_RATE:0.037037037037037035
# FALSE_POSITIVE_DISCOVERY_RATE:0.047619047619047616
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9290382819794584, 2: 0.878136200716846, 3: 0.8720865395338464}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9105544745272983
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=4
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8333333333333334
# RECALL:0.8214285714285715
# TRUE_NEGATIVE_RATE:0.9487179487179488
# FALSE_POSITIVE_RATE:0.05128205128205129
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.7857142857142857
# FB-MEASURE:{0.5: 0.8063271604938271, 2: 0.7934609250398724, 3: 0.8045385986562458}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7233783991441395
# GEOMETRIC_MEAN:0.8770152898402518
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=4
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8333333333333334
# RECALL:0.8214285714285715
# TRUE_NEGATIVE_RATE:0.9487179487179488
# FALSE_POSITIVE_RATE:0.05128205128205129
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.7857142857142857
# FB-MEASURE:{0.5: 0.8063271604938271, 2: 0.7934609250398724, 3: 0.8045385986562458}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7233783991441395
# GEOMETRIC_MEAN:0.8770152898402518
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=4
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8333333333333334
# RECALL:0.8214285714285715
# TRUE_NEGATIVE_RATE:0.9487179487179488
# FALSE_POSITIVE_RATE:0.05128205128205129
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.7857142857142857
# FB-MEASURE:{0.5: 0.8063271604938271, 2: 0.7934609250398724, 3: 0.8045385986562458}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7233783991441395
# GEOMETRIC_MEAN:0.8770152898402518
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9166666666666666
# RECALL:0.8968253968253969
# TRUE_NEGATIVE_RATE:0.9722222222222222
# FALSE_POSITIVE_RATE:0.027777777777777776
# FALSE_POSITIVE_DISCOVERY_RATE:0.08333333333333333
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9062513604109529, 2: 0.893973968897904, 3: 0.8949215933312731}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9320393789013889
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8333333333333334
# RECALL:0.8214285714285715
# TRUE_NEGATIVE_RATE:0.9487179487179488
# FALSE_POSITIVE_RATE:0.05128205128205129
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.7857142857142857
# FB-MEASURE:{0.5: 0.8063271604938271, 2: 0.7934609250398724, 3: 0.8045385986562458}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7233783991441395
# GEOMETRIC_MEAN:0.8770152898402518
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9166666666666666
# RECALL:0.8968253968253969
# TRUE_NEGATIVE_RATE:0.9722222222222222
# FALSE_POSITIVE_RATE:0.027777777777777776
# FALSE_POSITIVE_DISCOVERY_RATE:0.08333333333333333
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9062513604109529, 2: 0.893973968897904, 3: 0.8949215933312731}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9320393789013889
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8333333333333334
# RECALL:0.8214285714285715
# TRUE_NEGATIVE_RATE:0.9487179487179488
# FALSE_POSITIVE_RATE:0.05128205128205129
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.7857142857142857
# FB-MEASURE:{0.5: 0.8063271604938271, 2: 0.7934609250398724, 3: 0.8045385986562458}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7233783991441395
# GEOMETRIC_MEAN:0.8770152898402518
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=5
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=5
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=5
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=6
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9333333333333332
# RECALL:0.8857142857142857
# TRUE_NEGATIVE_RATE:0.9696969696969697
# FALSE_POSITIVE_RATE:0.030303030303030304
# FALSE_POSITIVE_DISCOVERY_RATE:0.06666666666666667
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9178187403993855, 2: 0.8893557422969188, 3: 0.8871671680337033}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9245699600060199
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=6
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9333333333333332
# RECALL:0.8857142857142857
# TRUE_NEGATIVE_RATE:0.9696969696969697
# FALSE_POSITIVE_RATE:0.030303030303030304
# FALSE_POSITIVE_DISCOVERY_RATE:0.06666666666666667
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9178187403993855, 2: 0.8893557422969188, 3: 0.8871671680337033}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9245699600060199
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=6
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9333333333333332
# RECALL:0.8857142857142857
# TRUE_NEGATIVE_RATE:0.9696969696969697
# FALSE_POSITIVE_RATE:0.030303030303030304
# FALSE_POSITIVE_DISCOVERY_RATE:0.06666666666666667
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9178187403993855, 2: 0.8893557422969188, 3: 0.8871671680337033}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# GEOMETRIC_MEAN:0.9245699600060199
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=7
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=7
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=7
# METRIC:  euclidean
#
#  INIT propagation
# iteration: tau=[146], p(tau) = 0.2828427124746411
#
#  END propagation in 8.58306884765625e-05 seconds with result=[0.         1.82675814 0.        ]
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8777777777777778
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.9023569023569024
# FB-MEASURE:{0.5: 0.9253294598122185, 2: 0.8856469201296787, 3: 0.8813921048645447}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8616178909971062
# GEOMETRIC_MEAN:0.9186604727419022
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
# RF Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=8
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=8
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=8
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=9
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.8333333333333334
# RECALL:0.8863636363636364
# TRUE_NEGATIVE_RATE:0.9761904761904763
# FALSE_POSITIVE_RATE:0.023809523809523808
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.8253968253968252
# FB-MEASURE:{0.5: 0.8244825708061002, 2: 0.8495776478232618, 3: 0.8652509569940764}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.7877814022935129
# GEOMETRIC_MEAN:0.9277040348964875
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=9
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.8333333333333334
# RECALL:0.8863636363636364
# TRUE_NEGATIVE_RATE:0.9761904761904763
# FALSE_POSITIVE_RATE:0.023809523809523808
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.8253968253968252
# FB-MEASURE:{0.5: 0.8244825708061002, 2: 0.8495776478232618, 3: 0.8652509569940764}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.7877814022935129
# GEOMETRIC_MEAN:0.9277040348964875
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=9
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.8333333333333334
# RECALL:0.8863636363636364
# TRUE_NEGATIVE_RATE:0.9761904761904763
# FALSE_POSITIVE_RATE:0.023809523809523808
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.8253968253968252
# FB-MEASURE:{0.5: 0.8244825708061002, 2: 0.8495776478232618, 3: 0.8652509569940764}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.7877814022935129
# GEOMETRIC_MEAN:0.9277040348964875
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.8333333333333334
# RECALL:0.8863636363636364
# TRUE_NEGATIVE_RATE:0.9761904761904763
# FALSE_POSITIVE_RATE:0.023809523809523808
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.8253968253968252
# FB-MEASURE:{0.5: 0.8244825708061002, 2: 0.8495776478232618, 3: 0.8652509569940764}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.7877814022935129
# GEOMETRIC_MEAN:0.9277040348964875
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.8333333333333334
# RECALL:0.8863636363636364
# TRUE_NEGATIVE_RATE:0.9761904761904763
# FALSE_POSITIVE_RATE:0.023809523809523808
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.8253968253968252
# FB-MEASURE:{0.5: 0.8244825708061002, 2: 0.8495776478232618, 3: 0.8652509569940764}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.7877814022935129
# GEOMETRIC_MEAN:0.9277040348964875
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.8333333333333334
# RECALL:0.8863636363636364
# TRUE_NEGATIVE_RATE:0.9761904761904763
# FALSE_POSITIVE_RATE:0.023809523809523808
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.8253968253968252
# FB-MEASURE:{0.5: 0.8244825708061002, 2: 0.8495776478232618, 3: 0.8652509569940764}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.7877814022935129
# GEOMETRIC_MEAN:0.9277040348964875
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.8333333333333334
# RECALL:0.8863636363636364
# TRUE_NEGATIVE_RATE:0.9761904761904763
# FALSE_POSITIVE_RATE:0.023809523809523808
# FALSE_POSITIVE_DISCOVERY_RATE:0.16666666666666666
# F1-MEASURE:0.8253968253968252
# FB-MEASURE:{0.5: 0.8244825708061002, 2: 0.8495776478232618, 3: 0.8652509569940764}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.7877814022935129
# GEOMETRIC_MEAN:0.9277040348964875
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=0
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=0
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=0
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8690476190476191
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.8964368964368964
# FB-MEASURE:{0.5: 0.9224369670003707, 2: 0.8777883623084861, 3: 0.8730627144949396}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8560177207724194
# GEOMETRIC_MEAN:0.9135096005358346
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=1
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=1
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=1
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8777777777777778
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.9023569023569024
# FB-MEASURE:{0.5: 0.9253294598122185, 2: 0.8856469201296787, 3: 0.8813921048645447}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8616178909971062
# GEOMETRIC_MEAN:0.9186604727419022
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=2
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9444444444444445
# RECALL:0.8777777777777778
# TRUE_NEGATIVE_RATE:0.9666666666666667
# FALSE_POSITIVE_RATE:0.03333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.05555555555555555
# F1-MEASURE:0.9023569023569024
# FB-MEASURE:{0.5: 0.9253294598122185, 2: 0.8856469201296787, 3: 0.8813921048645447}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8616178909971062
# GEOMETRIC_MEAN:0.9186604727419022
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=15, n=2
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8777777777777779
# RECALL:0.7666666666666666
# TRUE_NEGATIVE_RATE:0.9296296296296296
# FALSE_POSITIVE_RATE:0.07037037037037037
# FALSE_POSITIVE_DISCOVERY_RATE:0.12222222222222223
# F1-MEASURE:0.8111111111111112
# FB-MEASURE:{0.5: 0.8474747474747475, 2: 0.7825396825396825, 3: 0.7743295019157088}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7202570560327395
# GEOMETRIC_MEAN:0.8418958947251513
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=15, n=2
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8777777777777779
# RECALL:0.7666666666666666
# TRUE_NEGATIVE_RATE:0.9296296296296296
# FALSE_POSITIVE_RATE:0.07037037037037037
# FALSE_POSITIVE_DISCOVERY_RATE:0.12222222222222223
# F1-MEASURE:0.8111111111111112
# FB-MEASURE:{0.5: 0.8474747474747475, 2: 0.7825396825396825, 3: 0.7743295019157088}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7202570560327395
# GEOMETRIC_MEAN:0.8418958947251513
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:1.0
# PRECISION:1.0
# RECALL:1.0
# TRUE_NEGATIVE_RATE:1.0
# FALSE_POSITIVE_RATE:0.0
# FALSE_POSITIVE_DISCOVERY_RATE:0.0
# F1-MEASURE:1.0
# FB-MEASURE:{0.5: 1.0, 2: 1.0, 3: 1.0}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.0
# MATTEWS_CORRELATION_COEFICIENT:1.0
# GEOMETRIC_MEAN:1.0
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.8666666666666667
# PRECISION:0.8777777777777779
# RECALL:0.7666666666666666
# TRUE_NEGATIVE_RATE:0.9296296296296296
# FALSE_POSITIVE_RATE:0.07037037037037037
# FALSE_POSITIVE_DISCOVERY_RATE:0.12222222222222223
# F1-MEASURE:0.8111111111111112
# FB-MEASURE:{0.5: 0.8474747474747475, 2: 0.7825396825396825, 3: 0.7743295019157088}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.13333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.7202570560327395
# GEOMETRIC_MEAN:0.8418958947251513
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=IRIS STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=15, n=3
# METRIC:  euclidean
#
#  INIT propagation
# iteration: tau=[147], p(tau) = 0.1999999999999801
#
#  END propagation in 0.00018095970153808594 seconds with result=[14.12582234  0.          0.        ]
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.9333333333333332
# PRECISION:0.9523809523809524
# RECALL:0.8666666666666667
# TRUE_NEGATIVE_RATE:0.9629629629629629
# FALSE_POSITIVE_RATE:0.037037037037037035
# FALSE_POSITIVE_DISCOVERY_RATE:0.047619047619047616
# F1-MEASURE:0.9002849002849004
# FB-MEASURE:{0.5: 0.9290382819794584, 2: 0.878136200716846, 3: 0.8720865395338464}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.06666666666666667
# MATTEWS_CORRELATION_COEFICIENT:0.8594924305962843
# ...
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=30, n=7
# METRIC:  euclidean
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.6
# PRECISION:0.45714285714285713
# RECALL:0.24682539682539678
# TRUE_NEGATIVE_RATE:0.8746031746031747
# FALSE_POSITIVE_RATE:0.1253968253968254
# FALSE_POSITIVE_DISCOVERY_RATE:0.34285714285714286
# F1-MEASURE:0.3166666666666666
# FB-MEASURE:{0.5: 0.38619121513858357, 2: 0.2702699484394908, 3: 0.2579607325523841}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.4
# MATTEWS_CORRELATION_COEFICIENT:0.12730540263089485
# GEOMETRIC_MEAN:0.40634796248236854
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=30, n=7
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.7333333333333333
# PRECISION:0.5809523809523809
# RECALL:0.3781045751633987
# TRUE_NEGATIVE_RATE:0.923953823953824
# FALSE_POSITIVE_RATE:0.07604617604617606
# FALSE_POSITIVE_DISCOVERY_RATE:0.21904761904761907
# F1-MEASURE:0.4495726495726496
# FB-MEASURE:{0.5: 0.516808317751714, 2: 0.402498965289663, 3: 0.38973950026581605}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.26666666666666666
# MATTEWS_CORRELATION_COEFICIENT:0.3319380857316144
# GEOMETRIC_MEAN:0.5223465935896864
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=30, n=7
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.6333333333333333
# PRECISION:0.4904761904761905
# RECALL:0.2742657342657343
# TRUE_NEGATIVE_RATE:0.888910779622854
# FALSE_POSITIVE_RATE:0.11108922037714608
# FALSE_POSITIVE_DISCOVERY_RATE:0.30952380952380953
# F1-MEASURE:0.345892316999395
# FB-MEASURE:{0.5: 0.4174012051919028, 2: 0.2982942409521255, 3: 0.2856780121771913}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.36666666666666664
# MATTEWS_CORRELATION_COEFICIENT:0.17779115141247814
# GEOMETRIC_MEAN:0.43343895104828584
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:0.7666666666666667
# PRECISION:0.6095238095238095
# RECALL:0.41769480519480523
# TRUE_NEGATIVE_RATE:0.9346910755148741
# FALSE_POSITIVE_RATE:0.06530892448512586
# FALSE_POSITIVE_DISCOVERY_RATE:0.19047619047619047
# F1-MEASURE:0.48596078431372547
# FB-MEASURE:{0.5: 0.5500771158665896, 2: 0.4407817610673921, 3: 0.4286539939048074}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.23333333333333334
# MATTEWS_CORRELATION_COEFICIENT:0.384518779135947
# GEOMETRIC_MEAN:0.5528194151138905
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:0.8
# PRECISION:0.6345238095238095
# RECALL:0.4561111111111111
# TRUE_NEGATIVE_RATE:0.9436796536796537
# FALSE_POSITIVE_RATE:0.05632034632034631
# FALSE_POSITIVE_DISCOVERY_RATE:0.16547619047619047
# F1-MEASURE:0.525
# FB-MEASURE:{0.5: 0.583664546899841, 2: 0.4804095045500505, 3: 0.4678030303030303}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.2
# MATTEWS_CORRELATION_COEFICIENT:0.43447230231791617
# GEOMETRIC_MEAN:0.5814932680130678
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.8
# PRECISION:0.6083333333333334
# RECALL:0.44435897435897437
# TRUE_NEGATIVE_RATE:0.9531746031746031
# FALSE_POSITIVE_RATE:0.046825396825396826
# FALSE_POSITIVE_DISCOVERY_RATE:0.19166666666666668
# F1-MEASURE:0.48
# FB-MEASURE:{0.5: 0.5447547431048149, 2: 0.44550742183387726, 3: 0.4419262143121987}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.2
# MATTEWS_CORRELATION_COEFICIENT:0.41413025894712224
# GEOMETRIC_MEAN:0.5783019689471118
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.6666666666666666
# PRECISION:0.5
# RECALL:0.24362573099415202
# TRUE_NEGATIVE_RATE:0.9181481481481482
# FALSE_POSITIVE_RATE:0.08185185185185184
# FALSE_POSITIVE_DISCOVERY_RATE:0.3
# F1-MEASURE:0.32664835164835165
# FB-MEASURE:{0.5: 0.41187165775401074, 2: 0.2710997442455243, 3: 0.25661764705882356}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.3333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.19667339704568193
# GEOMETRIC_MEAN:0.37197782303929117
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=30, n=8
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.7333333333333333
# PRECISION:0.55
# RECALL:0.31333333333333335
# TRUE_NEGATIVE_RATE:0.9261111111111109
# FALSE_POSITIVE_RATE:0.07388888888888888
# FALSE_POSITIVE_DISCOVERY_RATE:0.45
# F1-MEASURE:0.39571428571428574
# FB-MEASURE:{0.5: 0.4736733854380913, 2: 0.34147374364765665, 3: 0.32676082171680115}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.26666666666666666
# MATTEWS_CORRELATION_COEFICIENT:0.25405130461727843
# GEOMETRIC_MEAN:0.4713997112845404
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=30, n=8
# METRIC:  euclidean
#
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.7666666666666667
# PRECISION:0.625
# RECALL:0.3672970304549252
# TRUE_NEGATIVE_RATE:0.9380372670807453
# FALSE_POSITIVE_RATE:0.06196273291925466
# FALSE_POSITIVE_DISCOVERY_RATE:0.375
# F1-MEASURE:0.4518797078948881
# FB-MEASURE:{0.5: 0.536160367011414, 2: 0.39583333333333337, 3: 0.3808784869953391}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.23333333333333334
# MATTEWS_CORRELATION_COEFICIENT:0.3384397095435488
# GEOMETRIC_MEAN:0.5197123162384314
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=30, n=8
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.7
# PRECISION:0.55
# RECALL:0.3021645021645022
# TRUE_NEGATIVE_RATE:0.9149395227198431
# FALSE_POSITIVE_RATE:0.08506047728015691
# FALSE_POSITIVE_DISCOVERY_RATE:0.45
# F1-MEASURE:0.38111065405183053
# FB-MEASURE:{0.5: 0.46258513019912806, 2: 0.32840909090909093, 3: 0.31460187623794283}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.3
# MATTEWS_CORRELATION_COEFICIENT:0.22669100947703885
# GEOMETRIC_MEAN:0.4624903875844386
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:0.6333333333333333
# PRECISION:0.5
# RECALL:0.24400816574729617
# TRUE_NEGATIVE_RATE:0.8959611304476024
# FALSE_POSITIVE_RATE:0.10403886955239763
# FALSE_POSITIVE_DISCOVERY_RATE:0.5
# F1-MEASURE:0.3143977591036414
# FB-MEASURE:{0.5: 0.3978184857252366, 2: 0.2661782661782661, 3: 0.2543487975807193}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.36666666666666664
# MATTEWS_CORRELATION_COEFICIENT:0.13168367166697584
# GEOMETRIC_MEAN:0.4102470527961765
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:0.6666666666666666
# PRECISION:0.525
# RECALL:0.27409090909090905
# TRUE_NEGATIVE_RATE:0.9052525252525252
# FALSE_POSITIVE_RATE:0.09474747474747475
# FALSE_POSITIVE_DISCOVERY_RATE:0.475
# F1-MEASURE:0.3483193277310924
# FB-MEASURE:{0.5: 0.43049450549450546, 2: 0.29814685314685313, 3: 0.28541033434650454}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.3333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.17956559241094747
# GEOMETRIC_MEAN:0.437406218883131
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.7666666666666667
# PRECISION:0.575
# RECALL:0.34067476383265854
# TRUE_NEGATIVE_RATE:0.9387114845938376
# FALSE_POSITIVE_RATE:0.061288515406162467
# FALSE_POSITIVE_DISCOVERY_RATE:0.425
# F1-MEASURE:0.42492417976288943
# FB-MEASURE:{0.5: 0.5022790807865435, 2: 0.36969696969696975, 3: 0.3545521028083365}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.23333333333333334
# MATTEWS_CORRELATION_COEFICIENT:0.30241541933761196
# GEOMETRIC_MEAN:0.49791381879587754
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.6666666666666666
# PRECISION:0.4
# RECALL:0.19797979797979798
# TRUE_NEGATIVE_RATE:0.9151515151515153
# FALSE_POSITIVE_RATE:0.08484848484848484
# FALSE_POSITIVE_DISCOVERY_RATE:0.6
# F1-MEASURE:0.26425339366515843
# FB-MEASURE:{0.5: 0.3314285714285714, 2: 0.22000000000000003, 3: 0.2084033613445378}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.3333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.08626701295064354
# GEOMETRIC_MEAN:0.2810431225085326
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=AVERAGE k=30, n=9
# METRIC:  euclidean
#
# PTDABC::AVERAGE Metrics
# <<<--------------------->>>
# ACCURACY:0.7333333333333333
# PRECISION:0.5283333333333333
# RECALL:0.33838383838383834
# TRUE_NEGATIVE_RATE:0.9297619047619048
# FALSE_POSITIVE_RATE:0.07023809523809524
# FALSE_POSITIVE_DISCOVERY_RATE:0.27166666666666667
# F1-MEASURE:0.39365079365079364
# FB-MEASURE:{0.5: 0.45712091900839635, 2: 0.3554576849501527, 3: 0.34623615472601305}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.26666666666666666
# MATTEWS_CORRELATION_COEFICIENT:0.27747585558814974
# GEOMETRIC_MEAN:0.48721805168337473
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=MAXIMAL k=30, n=9
# METRIC:  euclidean
# PTDABC::MAXIMAL Metrics
# <<<--------------------->>>
# ACCURACY:0.8
# PRECISION:0.5933333333333334
# RECALL:0.4193650793650793
# TRUE_NEGATIVE_RATE:0.9484472049689442
# FALSE_POSITIVE_RATE:0.0515527950310559
# FALSE_POSITIVE_DISCOVERY_RATE:0.20666666666666664
# F1-MEASURE:0.47327731092436964
# FB-MEASURE:{0.5: 0.5326678765880217, 2: 0.4360132748547801, 3: 0.42699147139174676}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.2
# MATTEWS_CORRELATION_COEFICIENT:0.38863387809546734
# GEOMETRIC_MEAN:0.5510778739680589
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# EXECUTE DATANAME=NORMAL STAGE=DEATH K-FOLD SEQUENCE_TYPE=NORMAL COMPLEX=RIPS DIM=3 SELECTOR=RANDOMIZED k=30, n=9
# METRIC:  euclidean
#
# PTDABC::RANDOMIZED Metrics
# <<<--------------------->>>
# ACCURACY:0.8
# PRECISION:0.5933333333333334
# RECALL:0.4193650793650793
# TRUE_NEGATIVE_RATE:0.9484472049689442
# FALSE_POSITIVE_RATE:0.0515527950310559
# FALSE_POSITIVE_DISCOVERY_RATE:0.20666666666666664
# F1-MEASURE:0.47327731092436964
# FB-MEASURE:{0.5: 0.5326678765880217, 2: 0.4360132748547801, 3: 0.42699147139174676}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.2
# MATTEWS_CORRELATION_COEFICIENT:0.38863387809546734
# GEOMETRIC_MEAN:0.5510778739680589
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# KNN Metrics
# <<<--------------------->>>
# ACCURACY:0.7666666666666667
# PRECISION:0.595
# RECALL:0.3883333333333333
# TRUE_NEGATIVE_RATE:0.9418181818181818
# FALSE_POSITIVE_RATE:0.05818181818181818
# FALSE_POSITIVE_DISCOVERY_RATE:0.205
# F1-MEASURE:0.43692307692307697
# FB-MEASURE:{0.5: 0.5064057564057564, 2: 0.4008485229415462, 3: 0.3935767886069059}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.23333333333333334
# MATTEWS_CORRELATION_COEFICIENT:0.35159536379001366
# GEOMETRIC_MEAN:0.528182733916317
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# WKNN Metrics
# <<<--------------------->>>
# ACCURACY:0.7666666666666667
# PRECISION:0.595
# RECALL:0.3883333333333333
# TRUE_NEGATIVE_RATE:0.9418181818181818
# FALSE_POSITIVE_RATE:0.05818181818181818
# FALSE_POSITIVE_DISCOVERY_RATE:0.205
# F1-MEASURE:0.43692307692307697
# FB-MEASURE:{0.5: 0.5064057564057564, 2: 0.4008485229415462, 3: 0.3935767886069059}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.23333333333333334
# MATTEWS_CORRELATION_COEFICIENT:0.35159536379001366
# GEOMETRIC_MEAN:0.528182733916317
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# LSVM Metrics
# <<<--------------------->>>
# ACCURACY:0.7333333333333333
# PRECISION:0.6
# RECALL:0.25874125874125875
# TRUE_NEGATIVE_RATE:0.9466666666666667
# FALSE_POSITIVE_RATE:0.05333333333333333
# FALSE_POSITIVE_DISCOVERY_RATE:0.2
# F1-MEASURE:0.35238095238095235
# FB-MEASURE:{0.5: 0.46143711361102663, 2: 0.28880398744044095, 3: 0.272866214224632}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.26666666666666666
# MATTEWS_CORRELATION_COEFICIENT:0.3027140427779411
# GEOMETRIC_MEAN:0.3880261352061203
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
#
# RF Metrics
# <<<--------------------->>>
# ACCURACY:0.6666666666666666
# PRECISION:0.425
# RECALL:0.23333333333333334
# TRUE_NEGATIVE_RATE:0.9200668896321069
# FALSE_POSITIVE_RATE:0.07993311036789297
# FALSE_POSITIVE_DISCOVERY_RATE:0.375
# F1-MEASURE:0.2807017543859649
# FB-MEASURE:{0.5: 0.34563492063492063, 2: 0.24586247086247087, 3: 0.23862224731789952}
# BALANCED_ACCURACY:0.0
# CLASSIFICATION_ERROR:0.3333333333333333
# MATTEWS_CORRELATION_COEFICIENT:0.14324910616490333
# GEOMETRIC_MEAN:0.3537076184296309
# SAMPLES:0
# ROC-AUC:{}
# PR-AUC:{}
#
# [[0.31666667 0.         0.         0.         0.68333333]
#  [0.1        0.1        0.7        0.1        0.        ]
#  [0.24       0.         0.52       0.         0.24      ]
#  [0.         0.         0.         1.         0.        ]
#  [0.3625     0.         0.0125     0.         0.625     ]]
# [[0.48333333 0.         0.         0.         0.51666667]
#  [0.         0.3        0.5        0.2        0.        ]
#  [0.16       0.         0.5        0.12       0.22      ]
#  [0.         0.         0.         1.         0.        ]
#  [0.3        0.         0.         0.0125     0.6875    ]]
# [[0.40666667 0.         0.01       0.04333333 0.54      ]
#  [0.         0.16       0.34       0.5        0.        ]
#  [0.156      0.         0.444      0.224      0.176     ]
#  [0.         0.         0.         1.         0.        ]
#  [0.3425     0.         0.005      0.03       0.6225    ]]
# [[0.45 0.   0.   0.   0.55]
#  [0.   0.1  0.9  0.   0.  ]
#  [0.12 0.   0.78 0.   0.1 ]
#  [0.   0.   0.   1.   0.  ]
#  [0.45 0.   0.   0.   0.55]]
# [[0.4        0.         0.01666667 0.         0.58333333]
#  [0.         0.1        0.9        0.         0.        ]
#  [0.12       0.         0.74       0.         0.14      ]
#  [0.         0.         0.         1.         0.        ]
#  [0.375      0.         0.         0.         0.625     ]]
# [[0.08333333 0.         0.01       0.         0.90666667]
#  [0.         0.16       0.84       0.         0.        ]
#  [0.02       0.06       0.912      0.         0.008     ]
#  [0.         0.         0.         1.         0.        ]
#  [0.0625     0.         0.         0.         0.9375    ]]
# [[0.12       0.         0.00666667 0.         0.87333333]
#  [0.         0.         0.02       0.84       0.14      ]
#  [0.164      0.         0.036      0.14       0.66      ]
#  [0.         0.         0.         1.         0.        ]
#  [0.1875     0.         0.0025     0.         0.81      ]]
# [[0.31666667 0.         0.         0.         0.68333333]
#  [0.1        0.1        0.7        0.1        0.        ]
#  [0.24       0.         0.52       0.         0.24      ]
#  [0.         0.         0.         1.         0.        ]
#  [0.3625     0.         0.0125     0.         0.625     ]]
# [[0.48333333 0.         0.         0.         0.51666667]
#  [0.         0.3        0.5        0.2        0.        ]
#  [0.16       0.         0.5        0.12       0.22      ]
#  [0.         0.         0.         1.         0.        ]
#  [0.3        0.         0.         0.0125     0.6875    ]]
# [[0.40666667 0.         0.01       0.04333333 0.54      ]
#  [0.         0.16       0.34       0.5        0.        ]
#  [0.156      0.         0.444      0.224      0.176     ]
#  [0.         0.         0.         1.         0.        ]
#  [0.3425     0.         0.005      0.03       0.6225    ]]
# [[0.45 0.   0.   0.   0.55]
#  [0.   0.1  0.9  0.   0.  ]
#  [0.12 0.   0.78 0.   0.1 ]
#  [0.   0.   0.   1.   0.  ]
#  [0.45 0.   0.   0.   0.55]]
# [[0.4        0.         0.01666667 0.         0.58333333]
#  [0.         0.1        0.9        0.         0.        ]
#  [0.12       0.         0.74       0.         0.14      ]
#  [0.         0.         0.         1.         0.        ]
#  [0.375      0.         0.         0.         0.625     ]]
# [[0.08333333 0.         0.01       0.         0.90666667]
#  [0.         0.16       0.84       0.         0.        ]
#  [0.02       0.06       0.912      0.         0.008     ]
#  [0.         0.         0.         1.         0.        ]
#  [0.0625     0.         0.         0.         0.9375    ]]
# [[0.12       0.         0.00666667 0.         0.87333333]
#  [0.         0.         0.02       0.84       0.14      ]
#  [0.164      0.         0.036      0.14       0.66      ]
#  [0.         0.         0.         1.         0.        ]
#  [0.1875     0.         0.0025     0.         0.81      ]]

# %%
kwargs = {"option": 1,   # this generates the datasets resulting plots  
                  "dtype": DatasetTypeHandler.KRNN,
                  "folder": "./docs/ADAC_TDABC_RESULTS",
                  "iterations": 0,
                  "number_of_datasets": 16,
                  "csv_output": True, "can_i_show":True,
                  "metric": "euclidean"}
TestKRNN_ROCAUC().execute(**kwargs)
# Out:
# ./docs/ADAC_TDABC_RESULTS/SWISSROLL/21.09.28_17.16.26/LSVM/LSVM-RIPS-3d-NORMAL_metrics.txt
# ./docs/ADAC_TDABC_RESULTS/SWISSROLL/21.09.28_17.16.26/RANDOMIZED/PTDABC-RIPS-3d-NORMAL_metrics.txt
# ./docs/ADAC_TDABC_RESULTS/SWISSROLL/21.09.28_17.16.26/KNN/KNN-RIPS-3d-NORMAL_metrics.txt
# ./docs/ADAC_TDABC_RESULTS/SWISSROLL/21.09.28_17.16.26/RF/RF-RIPS-3d-NORMAL_metrics.txt
# ./docs/ADAC_TDABC_RESULTS/SWISSROLL/21.09.28_17.16.26/WKNN/WKNN-RIPS-3d-NORMAL_metrics.txt
# ./docs/ADAC_TDABC_RESULTS/SWISSROLL/21.09.28_17.16.26/MAXIMAL/PTDABC-RIPS-3d-NORMAL_metrics.txt
# ./docs/ADAC_TDABC_RESULTS/SWISSROLL/21.09.28_17.16.26/AVERAGE/PTDABC-RIPS-3d-NORMAL_metrics.txt
# ERROR global: list index out of range
